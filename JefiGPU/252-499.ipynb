# %% [markdown]
# # 252 - 271

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x+z)*math.sin(time)*math.sin(y)
        if frequency ==1:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(y)-2*math.sin(y))*math.sin(x+z)
        if frequency ==2:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(y)*math.cos(x+z)*math.sin(time)-2*math.cos(time)*math.sin(y)*math.sin(x+z)
        if frequency ==3:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -(math.cos(y)*math.sin(time)+2*math.cos(time)*math.sin(y))*math.sin(x+z)
        if frequency ==4:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -3*math.cos(time)*math.sin(y)*math.sin(x+z)
        if frequency ==5:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = (-2*math.cos(time)+math.sin(time))*math.sin(y)*math.sin(x+z)
        if frequency ==6:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.sin(y)*(math.cos(x+z)+2*math.sin(x+z))
        if frequency ==7:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.sin(y)*(math.cos(x+z)*math.sin(time)-2*math.cos(time)*math.sin(x+z))
        if frequency ==8:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y)*(2*math.cos(x+z)+math.sin(x+z))
        if frequency ==9:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(y)*math.cos(x+z)*(2*math.cos(time)-math.sin(time))
        if frequency ==10:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(y)*(2*math.cos(time)*math.cos(x+z)-math.sin(time)*math.sin(x+z))
        if frequency ==11:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = 3*math.cos(time)*math.cos(y)*math.cos(x+z)
        if frequency ==12:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = 2*math.cos(time)*math.cos(y)*math.cos(x+z)+math.sin(time)*math.sin(y)*math.sin(x+z)
        if frequency ==13:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+z)*(2*math.cos(y)-math.sin(y))
        if frequency ==14:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(x+z)*(2*math.cos(time)*math.cos(y)+math.sin(time)*math.sin(y))
        if frequency ==15:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(y)*(-2*math.cos(x+z)*math.sin(time)+math.cos(time)*math.sin(x+z))
        if frequency ==16:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -3*math.cos(y)*math.cos(x+z)*math.sin(time)
        if frequency ==17:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(y)*math.sin(time)*(2*math.cos(x+z)+math.sin(x+z))
        if frequency ==18:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(y)*math.cos(x+z)*(math.cos(time)-2*math.sin(time))
        if frequency ==19:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -2*math.cos(y)*math.cos(x+z)*math.sin(time)-math.cos(time)*math.sin(y)*math.sin(x+z)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 272 - 291

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x+z)*(2*math.cos(y)*math.sin(time)+math.cos(time)*math.sin(y))
        if frequency ==1:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(x+z)*math.sin(time)*(-2*math.cos(y)+math.sin(y))
        if frequency ==2:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            rho[i_spatial] = -math.cos(z)*math.sin(time)*math.sin(x+y)+2*math.cos(time)*math.cos(x+y)*math.sin(z)
        if frequency ==3:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            rho[i_spatial] = math.cos(x+y)*(-math.cos(z)*math.sin(time)+2*math.cos(time)*math.sin(z))
        if frequency ==4:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y)*(math.cos(z)+2*math.sin(z))
        if frequency ==5:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(2*math.cos(x+y)-math.sin(x+y))*math.sin(z)
        if frequency ==6:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            rho[i_spatial] = (2*math.cos(time)*math.cos(x+y)+math.sin(time)*math.sin(x+y))*math.sin(z)
        if frequency ==7:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y)*math.sin(z)
        if frequency ==8:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            rho[i_spatial] = math.cos(x+y)*(2*math.cos(time)+math.sin(time))*math.sin(z)
        if frequency ==9:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.cos(z)*math.sin(x+y)-2*math.cos(x+y)*math.sin(time)*math.sin(z)
        if frequency ==10:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            rho[i_spatial] = -math.cos(x+y)*math.sin(time)*(math.cos(z)+2*math.sin(z))
        if frequency ==11:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            rho[i_spatial] = math.cos(x+y)*(math.cos(time)*math.cos(z)-2*math.sin(time)*math.sin(z))
        if frequency ==12:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            rho[i_spatial] = -(2*math.cos(x+y)*math.sin(time)+math.cos(time)*math.sin(x+y))*math.sin(z)
        if frequency ==13:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            rho[i_spatial] = math.sin(time)*(-2*math.cos(x+y)+math.sin(x+y))*math.sin(z)
        if frequency ==14:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            rho[i_spatial] = -math.cos(x+y)*(math.cos(time)+2*math.sin(time))*math.sin(z)
        if frequency ==15:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            rho[i_spatial] = -math.cos(x+y)*math.sin(time)*math.sin(z)
        if frequency ==16:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.sin(x+y)*(math.cos(z)-2*math.sin(z))
        if frequency ==17:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            rho[i_spatial] = -math.cos(x+y)*math.cos(z)*math.sin(time)-2*math.cos(time)*math.sin(x+y)*math.sin(z)
        if frequency ==18:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            rho[i_spatial] = -math.sin(x+y)*(math.cos(z)*math.sin(time)+2*math.cos(time)*math.sin(z))
        if frequency ==19:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            rho[i_spatial] = -3*math.cos(time)*math.sin(x+y)*math.sin(z)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 292 - 311

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            rho[i_spatial] = (-2*math.cos(time)+math.sin(time))math.sin(x+y)*math.sin(z)
        if frequency ==1:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            rho[i_spatial] = -math.cos(time)*(math.cos(x+y)+2*math.sin(x+y))math.sin(z)
        if frequency ==2:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            rho[i_spatial] = (math.cos(x+y)*math.sin(time)-2*math.cos(time)*math.sin(x+y))math.sin(z)
        if frequency ==3:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.cos(z)*(2*math.cos(x+y)+math.sin(x+y))
        if frequency ==4:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            rho[i_spatial] = math.cos(x+y)*math.cos(z)*(2*math.cos(time)-math.sin(time))
        if frequency ==5:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            rho[i_spatial] = math.cos(z)*(2*math.cos(time)*math.cos(x+y)-math.sin(time)*math.sin(x+y))
        if frequency ==6:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            rho[i_spatial] = 3*math.cos(time)*math.cos(x+y)*math.cos(z)
        if frequency ==7:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            rho[i_spatial] = 2*math.cos(time)*math.cos(x+y)*math.cos(z)+math.sin(time)*math.sin(x+y)*math.sin(z)
        if frequency ==8:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y)*(2*math.cos(z)-math.sin(z))
        if frequency ==9:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            rho[i_spatial] = math.cos(x+y)*(2*math.cos(time)*math.cos(z)+math.sin(time)*math.sin(z))
        if frequency ==10:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            rho[i_spatial] = math.cos(z)*(-2*math.cos(x+y)*math.sin(time)+math.cos(time)*math.sin(x+y))
        if frequency ==11:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            rho[i_spatial] = -3*math.cos(x+y)*math.cos(z)*math.sin(time)
        if frequency ==12:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            rho[i_spatial] = -math.cos(z)*math.sin(time)*(2*math.cos(x+y)+math.sin(x+y))
        if frequency ==13:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            rho[i_spatial] = math.cos(x+y)*math.cos(z)*(math.cos(time)-2*math.sin(time))
        if frequency ==14:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            rho[i_spatial] = -2*math.cos(x+y)*math.cos(z)*math.sin(time)-math.cos(time)*math.sin(x+y)*math.sin(z)
        if frequency ==15:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            rho[i_spatial] = -math.cos(x+y)*(2*math.cos(z)*math.sin(time)+math.cos(time)*math.sin(z))
        if frequency ==16:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            rho[i_spatial] = math.cos(x+y)*math.sin(time)*(-2*math.cos(z)+math.sin(z))
        if frequency ==17:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x+y)*math.sin(time)*math.sin(z)+math.cos(time)*math.sin(x+y+z)
        if frequency ==18:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(z)*math.sin(x+y)+math.cos(time-x-y)*math.sin(z)
        if frequency ==19:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.sin(x+y)*(math.cos(z)-math.sin(z))+math.cos(x+y)*math.sin(z))
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 312 - 331

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(z)*math.sin(x+y)+math.cos(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==1:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x+y)*math.cos(z)*math.sin(time)+math.cos(time)*math.sin(x+y+z)
        if frequency ==2:
            Jx[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y)*math.sin(z)
        if frequency ==3:
            Jx[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(z)*math.sin(time)*math.sin(x+y)+math.cos(time)*math.sin(x+y+z)
        if frequency ==4:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y)*math.sin(z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==5:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.sin(x+y)*(math.cos(z)-math.sin(z))+math.cos(x+y)*math.sin(z))
        if frequency ==6:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(z)*math.sin(time)*math.sin(x+y)-math.sin(time+x+y)*math.sin(z)
        if frequency ==7:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y)*math.cos(z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==8:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(z)*math.sin(x+y)+math.cos(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==9:
            Jx[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.cos(z)*math.sin(x+y)-math.sin(time)*math.sin(x+y+z)
        if frequency ==10:
            Jx[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x+y)*math.sin(time)*math.sin(z)
        if frequency ==11:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(-math.sin(x+y)*math.sin(z)+math.cos(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==12:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(x+y)*math.sin(z)
        if frequency ==13:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x+y)*math.sin(time)*math.sin(z)
        if frequency ==14:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(2*math.cos(x+y)*math.cos(z)-math.sin(x+y)*math.sin(z))
        if frequency ==15:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x+y)*math.cos(z)*math.sin(time)
        if frequency ==16:
            Jx[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x+y)*math.cos(z)-math.sin(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==17:
            Jx[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.cos(z)*math.sin(time)*math.sin(x+y)
        if frequency ==18:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(-math.sin(x+y)*math.sin(z)+math.cos(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==19:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(x+y)*math.sin(z)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 332 - 351

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x+y)*math.sin(time)*math.sin(z)
        if frequency ==1:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x+y)*math.cos(z)-2*math.sin(x+y)*math.sin(z))
        if frequency ==2:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x+y)*math.cos(z)*math.sin(time)
        if frequency ==3:
            Jx[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x+y)*math.cos(z)-math.sin(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==4:
            Jx[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.cos(z)*math.sin(time)*math.sin(x+y)
        if frequency ==5:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)+math.cos(time)*math.cos(x+y)*math.sin(z)
        if frequency ==6:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(x+y)*math.cos(z)+2*math.sin(x+y)*math.sin(z))
        if frequency ==7:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*(math.sin(x+y)*math.sin(z)-math.cos(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==8:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)-math.cos(time)*math.sin(x+y)*math.sin(z)
        if frequency ==9:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y)*math.cos(z)-math.cos(x+y+z)*math.sin(time)
        if frequency ==10:
            Jx[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)-math.cos(time)*math.cos(z)*math.sin(x+y)
        if frequency ==11:
            Jx[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(x+y)*math.cos(z)+math.sin(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==12:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x+y)*math.sin(time)*math.sin(z)+math.cos(time)*math.sin(x+y+z)
        if frequency ==13:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(z)*math.sin(x+y)+math.cos(time-x-y)*math.sin(z)
        if frequency ==14:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.sin(x+y)*(math.cos(z)-math.sin(z))+math.cos(x+y)*math.sin(z))
        if frequency ==15:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(z)*math.sin(x+y)+math.cos(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==16:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x+y)*math.cos(z)*math.sin(time)+math.cos(time)*math.sin(x+y+z)
        if frequency ==17:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y)*math.sin(z)
        if frequency ==18:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(z)*math.sin(time)*math.sin(x+y)+math.cos(time)*math.sin(x+y+z)
        if frequency ==19:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y)*math.sin(z)-math.sin(time)*math.sin(x+y+z)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 352 - 371

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.sin(x+y)*(math.cos(z)-math.sin(z))+math.cos(x+y)*math.sin(z))
        if frequency ==1:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(z)*math.sin(time)*math.sin(x+y)-math.sin(time+x+y)*math.sin(z)
        if frequency ==2:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y)*math.cos(z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==3:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(z)*math.sin(x+y)+math.cos(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==4:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.cos(z)*math.sin(x+y)-math.sin(time)*math.sin(x+y+z)
        if frequency ==5:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x+y)*math.sin(time)*math.sin(z)
        if frequency ==6:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(-math.sin(x+y)*math.sin(z)+math.cos(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==7:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(x+y)*math.sin(z)
        if frequency ==8:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x+y)*math.sin(time)*math.sin(z)
        if frequency ==9:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(2*math.cos(x+y)*math.cos(z)-math.sin(x+y)*math.sin(z))
        if frequency ==10:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x+y)*math.cos(z)*math.sin(time)
        if frequency ==11:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x+y)*math.cos(z)-math.sin(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==12:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.cos(z)*math.sin(time)*math.sin(x+y)
        if frequency ==13:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(-math.sin(x+y)*math.sin(z)+math.cos(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==14:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(x+y)*math.sin(z)
        if frequency ==15:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x+y)*math.sin(time)*math.sin(z)
        if frequency ==16:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x+y)*math.cos(z)-2*math.sin(x+y)*math.sin(z))
        if frequency ==17:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x+y)*math.cos(z)*math.sin(time)
        if frequency ==18:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x+y)*math.cos(z)-math.sin(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==19:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.cos(z)*math.sin(time)*math.sin(x+y)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 372 - 391

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)+math.cos(time)*math.cos(x+y)*math.sin(z)
        if frequency ==1:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(x+y)*math.cos(z)+2*math.sin(x+y)*math.sin(z))
        if frequency ==2:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.sin(time)*(math.sin(x+y)*math.sin(z)-math.cos(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==3:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)-math.cos(time)*math.sin(x+y)*math.sin(z)
        if frequency ==4:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y)*math.cos(z)-math.cos(x+y+z)*math.sin(time)
        if frequency ==5:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)-math.cos(time)*math.cos(z)*math.sin(x+y)
        if frequency ==6:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(x+y)*math.cos(z)+math.sin(x+y)*(math.cos(z)+math.sin(z)))
        if frequency ==7:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(z)*math.sin(x)*math.sin(y)+math.sin(x+y)*math.sin(z))
        if frequency ==8:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(y)*math.cos(z)*math.sin(x)+math.cos(x+y)*math.sin(z))
        if frequency ==9:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(y)*math.cos(z)*math.sin(x)+math.cos(x+z)*math.sin(y))
        if frequency ==10:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(z)*math.sin(x)*math.sin(y)+math.sin(x+y)*math.sin(z))
        if frequency ==11:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y)*math.cos(z)-math.sin(x)*math.sin(y+z))
        if frequency ==12:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(y)*math.cos(z)*math.sin(x)+math.cos(x+y)*math.sin(z))
        if frequency ==13:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(y)*math.cos(z)*math.sin(x)+math.cos(x+z)*math.sin(y))
        if frequency ==14:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(x)*math.cos(y)*math.cos(z)+math.sin(x)*math.sin(y+z))
        if frequency ==15:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(z)*math.sin(y)+math.cos(x+y)*math.sin(z))
        if frequency ==16:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y+z)-math.cos(y)*math.sin(x)*math.sin(z))
        if frequency ==17:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y+z)-math.cos(z)*math.sin(x)*math.sin(y))
        if frequency ==18:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(x)*math.cos(z)*math.sin(y)+math.cos(x+y)*math.sin(z))
        if frequency ==19:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(time)*(math.cos(x)*math.cos(z)*math.sin(y)+math.cos(y)*math.sin(x+z))
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 392 - 411

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(x)*math.cos(y+z)+math.cos(y)*math.sin(x)*math.sin(z))
        if frequency ==1:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(x)*math.cos(y+z)+math.cos(z)*math.sin(x)*math.sin(y))
        if frequency ==2:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*(math.cos(x)*math.cos(z)*math.sin(y)+math.cos(y)*math.sin(x+z))
        if frequency ==3:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y)*math.sin(z)+math.sin(x)*math.sin(y+z))
        if frequency ==4:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(z)*math.sin(y)+math.sin(x)*math.sin(y+z))
        if frequency ==5:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x)*math.sin(time)*math.sin(y)*math.sin(z)+math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==6:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y)*math.cos(z)+math.sin(x)*math.sin(y+z))
        if frequency ==7:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(z)*math.sin(x)*math.sin(y)-math.cos(y)*math.sin(time-x)*math.sin(z)
        if frequency ==8:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x)*math.cos(z)*math.sin(time)*math.sin(y)+math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==9:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x)*math.cos(y)*math.cos(z)*math.sin(time)+math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==10:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.sin(x)*(math.cos(z)*math.sin(y)+(math.cos(y)-math.sin(y))*math.sin(z))
        if frequency ==11:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(z)*math.sin(x)*math.sin(y)
        if frequency ==12:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y)*math.sin(x)*math.sin(z)
        if frequency ==13:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.cos(time)*math.cos(z)*math.sin(y)+math.cos(time-y)*math.sin(z))
        if frequency ==14:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.sin(x)*(math.cos(z)*math.sin(y)+math.cos(y)*(-math.cos(z)+math.sin(z)))
        if frequency ==15:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.cos(y)*math.sin(time)*math.sin(z)+math.cos(time)*math.sin(y+z))
        if frequency ==16:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.cos(z)*math.sin(time)*math.sin(y)+math.cos(time)*math.sin(y+z))
        if frequency ==17:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.cos(y)*math.cos(z)*math.sin(time)+math.cos(time)*math.sin(y+z))
        if frequency ==18:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(y)*math.cos(z)*math.sin(x)+math.cos(x+z)*math.sin(y))
        if frequency ==19:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(y+z)*math.sin(x)+math.cos(x)*math.sin(y)*math.sin(z))
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 412 - 431

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*math.sin(x)-math.cos(x)*math.sin(time)*math.sin(y)*math.sin(z)
        if frequency ==1:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y)*math.cos(z)+math.cos(y+z)*math.sin(x))
        if frequency ==2:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*math.sin(x)-math.cos(x)*math.cos(y)*math.sin(time)*math.sin(z)
        if frequency ==3:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*math.sin(x)-math.cos(x)*math.cos(z)*math.sin(time)*math.sin(y)
        if frequency ==4:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x)*math.cos(y)*math.cos(z)*math.sin(time)+math.cos(time)*math.cos(y+z)*math.sin(x)
        if frequency ==5:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.sin(x)*(math.cos(y)*math.cos(z)-2*math.sin(y)*math.sin(z))
        if frequency ==6:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.sin(x)*(math.cos(y)*math.cos(z)-(math.cos(y)+math.sin(y))*math.sin(z))
        if frequency ==7:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.sin(x)*(math.cos(y)*math.cos(z)-math.sin(y)*(math.cos(z)+math.sin(z)))
        if frequency ==8:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.cos(time)*math.cos(y+z)+math.sin(time)*math.sin(y)*math.sin(z))
        if frequency ==9:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.sin(x)*math.sin(y)*math.sin(z)
        if frequency ==10:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.cos(time)*math.cos(y)*math.cos(z)+math.sin(time-y)*math.sin(z))
        if frequency ==11:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.cos(time)*math.cos(y+z)+math.cos(z)*math.sin(time)*math.sin(y))
        if frequency ==12:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = (math.cos(time)*math.cos(y+z)+math.cos(y)*math.cos(z)*math.sin(time))*math.sin(x)
        if frequency ==13:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(y)*math.cos(z)*math.sin(x)+math.cos(x+y)*math.sin(z))
        if frequency ==14:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(y+z)*math.sin(x)+math.cos(x)*math.sin(y)*math.sin(z))
        if frequency ==15:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*math.sin(x)-math.cos(x)*math.sin(time)*math.sin(y)*math.sin(z)
        if frequency ==16:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y)*math.cos(z)+math.cos(y+z)*math.sin(x))
        if frequency ==17:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*math.sin(x)-math.cos(x)*math.cos(y)*math.sin(time)*math.sin(z)
        if frequency ==18:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*math.sin(x)-math.cos(x)*math.cos(z)*math.sin(time)*math.sin(y)
        if frequency ==19:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x)*math.cos(y)*math.cos(z)*math.sin(time)+math.cos(time)*math.cos(y+z)*math.sin(x)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 432 - 451

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.sin(x)*(math.cos(y)*math.cos(z)-2*math.sin(y)*math.sin(z))
        if frequency ==1:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.sin(x)*(math.cos(y)*math.cos(z)-(math.cos(y)+math.sin(y))*math.sin(z))
        if frequency ==2:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.sin(x)*(math.cos(y)*math.cos(z)-math.sin(y)*(math.cos(z)+math.sin(z)))
        if frequency ==3:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.cos(time)*math.cos(y+z)+math.sin(time)*math.sin(y)*math.sin(z))
        if frequency ==4:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.sin(x)*math.sin(y)*math.sin(z)
        if frequency ==5:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.cos(time)*math.cos(y)*math.cos(z)+math.sin(time-y)*math.sin(z))
        if frequency ==6:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.cos(time)*math.cos(y+z)+math.cos(z)*math.sin(time)*math.sin(y))
        if frequency ==7:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = (math.cos(time)*math.cos(y+z)+math.cos(y)*math.cos(z)*math.sin(time))*math.sin(x)
        if frequency ==8:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x)*math.sin(y)*math.sin(z)-math.sin(time)*math.sin(x)*math.sin(y+z)
        if frequency ==9:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x)*math.cos(y)*math.sin(z)-math.sin(time)*math.sin(x)*math.sin(y+z)
        if frequency ==10:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x)*math.cos(z)*math.sin(y)-math.sin(time)*math.sin(x)*math.sin(y+z)
        if frequency ==11:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x)*math.cos(y)*math.cos(z)-math.sin(time)*math.sin(x)*math.sin(y+z)
        if frequency ==12:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(x)*math.cos(y)*math.sin(z)+math.sin(x)*math.sin(y+z))
        if frequency ==13:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(x)*math.cos(z)*math.sin(y)+math.sin(x)*math.sin(y+z))
        if frequency ==14:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(x)*math.cos(y)*math.cos(z)+math.sin(x)*math.sin(y+z))
        if frequency ==15:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(x)*(math.cos(z)*math.sin(time)*math.sin(y)+math.sin(time+y)*math.sin(z))
        if frequency ==16:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(x)*(math.cos(time)*math.cos(y)*math.sin(z)+math.sin(time)*math.sin(y+z))
        if frequency ==17:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(x)*(math.cos(time)*math.cos(z)*math.sin(y)+math.sin(time)*math.sin(y+z))
        if frequency ==18:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*math.sin(x)*(math.cos(z)*math.sin(y)+(math.cos(y)-math.sin(y))*math.sin(z))
        if frequency ==19:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(x)*(math.cos(y)*math.cos(time-z)+math.cos(z)*math.sin(time)*math.sin(y))
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 452 - 471

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(z)*math.sin(time)*math.sin(x)*math.sin(y)
        if frequency ==1:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(y)*math.sin(time)*math.sin(x)*math.sin(z)
        if frequency ==2:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*math.sin(x)*(-math.cos(z)*math.sin(y)+math.cos(y)*(math.cos(z)-math.sin(z)))
        if frequency ==3:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(time)*(math.cos(z)*math.sin(x)*math.sin(y)+math.sin(x-y)*math.sin(z))
        if frequency ==4:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y)*math.sin(z)-math.sin(x)*math.sin(y+z))
        if frequency ==5:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(z)*math.sin(y)-math.sin(x)*math.sin(y+z))
        if frequency ==6:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x)*math.sin(time)*math.sin(y)*math.sin(z)-math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==7:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x)*math.cos(y)*math.sin(time)*math.sin(z)-math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==8:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x)*math.cos(z)*math.sin(time)*math.sin(y)-math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==9:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x)*math.cos(y)*math.cos(z)*math.sin(time)-math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==10:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.sin(x)*(math.cos(z)*math.sin(y)+(math.cos(y)+math.sin(y))*math.sin(z))
        if frequency ==11:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.sin(x)*(math.cos(z)*math.sin(y)+2*math.cos(y)*math.sin(z))
        if frequency ==12:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.sin(x)*(2*math.cos(z)*math.sin(y)+math.cos(y)*math.sin(z))
        if frequency ==13:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.sin(time)*math.sin(y)*math.sin(z)-math.cos(time)*math.sin(y+z))
        if frequency ==14:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.sin(x)*(math.cos(z)*math.sin(y)+math.cos(y)*(math.cos(z)+math.sin(z)))
        if frequency ==15:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.cos(y)*math.sin(time)*math.sin(z)-math.cos(time)*math.sin(y+z))
        if frequency ==16:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.cos(z)*math.sin(time)*math.sin(y)-math.cos(time)*math.sin(y+z))
        if frequency ==17:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.cos(y)*math.cos(z)*math.sin(time)-math.cos(time)*math.sin(y+z))
        if frequency ==18:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(y+z)*math.sin(time)*math.sin(x)+math.cos(time)*math.cos(x)*math.sin(y)*math.sin(z)
        if frequency ==19:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(y+z)*math.sin(time)*math.sin(x)+math.cos(time)*math.cos(x)*math.cos(y)*math.sin(z)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 472 - 491

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(y+z)*math.sin(time)*math.sin(x)+math.cos(time)*math.cos(x)*math.cos(z)*math.sin(y)
        if frequency ==1:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(y+z)*math.sin(x)+math.cos(x)*math.sin(y)*math.sin(z))
        if frequency ==2:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time+x)*math.cos(y)*math.cos(z)+math.sin(time)*math.sin(x)*math.sin(y)*math.sin(z)
        if frequency ==3:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(y)*math.cos(z)*math.sin(x)+math.cos(x+z)*math.sin(y))
        if frequency ==4:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(x)*math.cos(y)*math.cos(z)+math.cos(y+z)*math.sin(x))
        if frequency ==5:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(x)*(math.cos(y+z)*math.sin(time)+math.cos(time)*math.sin(y)*math.sin(z))
        if frequency ==6:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(x)*(math.cos(y+z)*math.sin(time)+math.cos(time)*math.cos(y)*math.sin(z))
        if frequency ==7:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(x)*(math.cos(y+z)*math.sin(time)+math.cos(time)*math.cos(z)*math.sin(y))
        if frequency ==8:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*math.sin(x)*(-math.cos(y)*math.cos(z)+2*math.sin(y)*math.sin(z))
        if frequency ==9:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -(math.cos(time)*math.cos(y)*math.cos(z)+math.cos(y+z)*math.sin(time))*math.sin(x)
        if frequency ==10:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*math.sin(x)*(-math.cos(y)*math.cos(z)+(math.cos(y)+math.sin(y))*math.sin(z))
        if frequency ==11:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*math.sin(x)*(-math.cos(y)*math.cos(z)+math.sin(y)*(math.cos(z)+math.sin(z)))
        if frequency ==12:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*math.sin(x)*math.sin(y)*math.sin(z)
        if frequency ==13:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x)*math.sin(y)*math.sin(z)+math.sin(time)*math.sin(x)*math.sin(y+z)
        if frequency ==14:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x)*math.cos(y)*math.sin(z)+math.sin(time)*math.sin(x)*math.sin(y+z)
        if frequency ==15:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x)*math.cos(z)*math.sin(y)+math.sin(time)*math.sin(x)*math.sin(y+z)
        if frequency ==16:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*(math.cos(z)*math.sin(x)*math.sin(y)+math.sin(x-y)*math.sin(z))
        if frequency ==17:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x)*math.cos(y)*math.cos(z)+math.sin(time)*math.sin(x)*math.sin(y+z)
        if frequency ==18:
            Jx[i_spatial] = math.sin(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(x)*math.cos(y)*math.sin(z)+math.sin(x)*math.sin(y+z))
        if frequency ==19:
            Jx[i_spatial] = math.sin(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(x)*math.cos(z)*math.sin(y)+math.sin(x)*math.sin(y+z))
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 492 - 499

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(-math.cos(time)*math.sin(y)*math.sin(z)+math.sin(time)*math.sin(y+z))
        if frequency ==1:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(-math.cos(time)*math.cos(y)*math.sin(z)+math.sin(time)*math.sin(y+z))
        if frequency ==2:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(-math.cos(time)*math.cos(z)*math.sin(y)+math.sin(time)*math.sin(y+z))
        if frequency ==3:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*math.sin(x)*(math.cos(z)*math.sin(y)+(math.cos(y)+math.sin(y))*math.sin(z))
        if frequency ==4:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(-math.cos(time)*math.cos(y)*math.cos(z)+math.sin(time)*math.sin(y+z))
        if frequency ==5:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.sin(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*math.sin(x)*(math.cos(z)*math.sin(y)+2*math.cos(y)*math.sin(z))
        if frequency ==6:
            Jx[i_spatial] = math.cos(x)*math.sin(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*math.sin(x)*(2*math.cos(z)*math.sin(y)+math.cos(y)*math.sin(z))
        if frequency ==7:
            Jx[i_spatial] = math.cos(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y)*math.cos(z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*math.sin(x)*(math.cos(z)*math.sin(y)+math.cos(y)*(math.cos(z)+math.sin(z)))
    return Jx, Jy, Jz, rho
