# %% [markdown]
# # 0-11

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = 3*(math.cos(time)-1)*math.cos(x+y+z)
        if frequency ==1:
            Jx[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = 3*math.sin(time)*math.sin(x+y+z)
        if frequency ==2:
            Jx[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = (-3*math.sin(time))*math.cos(x+y+z)
        if frequency ==3:
            Jx[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = (-3*(math.cos(time)-1))*math.sin(x+y+z)
        if frequency ==4:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = 2*(math.cos(time)-1)*math.cos(y+z)*math.sin(x)+(math.cos(time)-1)*math.cos(x)*math.sin(y+z)
        if frequency ==5:
            Jx[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(y+z)*math.sin(time)*math.sin(x)+2*math.cos(x)*math.sin(time)*math.sin(y+z) 
        if frequency ==6:
            Jx[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.cos(y+z)*math.sin(x)-2*math.cos(time)*math.cos(x)*math.sin(y+z)
        if frequency ==7:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -2*math.cos(y+z)*math.sin(time)*math.sin(x)-math.cos(x)*math.sin(time)*math.sin(y+z)
        if frequency ==8:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = 2*math.cos(time)*math.cos(x)*math.cos(y+z)-math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==9:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x)*math.cos(y+z)*math.sin(time)+2*math.sin(time)*math.sin(x)*math.sin(y+z)
        if frequency ==10:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x)*math.cos(y+z)-2*math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==11:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -2*math.cos(x)*math.cos(y+z)*math.sin(time)+math.sin(time)*math.sin(x)*math.sin(y+z)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 12-31

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = 2*math.cos(time)*math.cos(x+z)*math.sin(y)+math.cos(time)*math.cos(y)*math.sin(x+z)
        if frequency ==1:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -2*math.cos(x+z)*math.sin(time)*math.sin(y)-1*math.cos(y)*math.sin(time)*math.sin(x+z)
        if frequency ==2:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -1*math.cos(y)*math.cos(x+z)*math.sin(time)+2*math.sin(time)*math.sin(y)*math.sin(x+z)
        if frequency ==3:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y)*math.cos(x+z)-2*math.cos(time)*math.sin(y)*math.sin(x+z)
        if frequency ==4:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = 2*math.cos(time)*math.cos(y)*math.cos(x+z)-1*math.cos(time)*math.sin(y)*math.sin(x+z)
        if frequency ==5:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -2*math.cos(y)*math.cos(x+z)*math.sin(time)+math.sin(time)*math.sin(y)*math.sin(x+z) 
        if frequency ==6:
            Jx[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(x+z)*math.sin(time)*math.sin(y)+2*math.cos(y)*math.sin(time)*math.sin(x+z)
        if frequency ==7:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -2*math.cos(y)*math.cos(x+z)*math.sin(time)+math.sin(time)*math.sin(y)*math.sin(x+z)
        if frequency ==8:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(z)*math.sin(x+y)+2*math.cos(time)*math.cos(x+y)*math.sin(z)
        if frequency ==9:
            Jx[i_spatial] = math.sin(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y)*math.cos(z)-2*math.cos(time)*math.sin(x+y)*math.sin(z)
        if frequency ==10:
            Jx[i_spatial] = math.sin(z)*math.cos(y+x)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -1*math.cos(x+y)*math.cos(z)*math.sin(time)+2*math.sin(time)*math.sin(x+y)*math.sin(z)
        if frequency ==11:
            Jx[i_spatial] = math.sin(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -1*math.cos(z)*math.sin(time)*math.sin(x+y)-2*math.cos(x+y)*math.sin(time)*math.sin(z)
        if frequency ==12:
            Jx[i_spatial] = math.cos(z)*math.cos(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = 2*math.cos(z)*math.sin(time)*math.sin(x+y)+math.cos(x+y)*math.sin(time)*math.sin(z)   
        if frequency ==13:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -2*math.cos(x+y)*math.cos(z)*math.sin(time)+math.sin(time)*math.sin(x+y)*math.sin(z)
        if frequency ==14:
            Jx[i_spatial] = math.cos(z)*math.sin(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = 2*math.cos(time)*math.cos(x+y)*math.cos(z)-1*math.cos(time)*math.sin(x+y)*math.sin(z)
        if frequency ==15:
            Jx[i_spatial] = math.cos(z)*math.cos(x+y)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -2*math.cos(time)*math.cos(z)*math.sin(x+y)-1*math.cos(time)*math.cos(x+y)*math.sin(z)
        if frequency ==16:
            Jx[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x+y+z)*math.cos(time)
            rho[i_spatial] = 2*math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(x+y+z)
        if frequency ==17:
            Jx[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x+y+z)*math.cos(time)
            rho[i_spatial] = 2*math.cos(time)*math.cos(x+y+z)-math.sin(time)*math.cos(x+y+z)
        if frequency ==18:
            Jx[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x+y+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(2*math.cos(x+y+z)-math.sin(x+y+z))
        if frequency ==19:
            Jx[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x+y+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+2*math.sin(time)*math.sin(x+y+z)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 32-51

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x+y+z)*math.cos(time)
            rho[i_spatial] = -1*math.sin(time)*(math.cos(x+y+z)-2*math.sin(x+y+z))
        if frequency ==1:
            Jx[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x+y+z)*math.sin(time)
            rho[i_spatial] = -1*math.sin(x+y+z)*(math.cos(time)-2*math.sin(time))
        if frequency ==2:
            Jx[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x+y+z)*math.sin(time)
            rho[i_spatial] = math.cos(x+y+z)*(math.cos(time)-2*math.sin(time))
        if frequency ==3:
            Jx[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x+y+z)*math.cos(time)
            rho[i_spatial] = math.sin(time)*(-2*math.cos(x+y+z)+math.sin(x+y+z))
        if frequency ==4:
            Jx[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x+y+z)*math.sin(time)
            rho[i_spatial] = -2*math.sin(time)*math.cos(x+y+z)-1*math.cos(time)*math.sin(x+y+z)
        if frequency ==5:
            Jx[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x+y+z)*math.sin(time)
            rho[i_spatial] = -math.sin(time)*(math.cos(x+y+z)-2*math.sin(x+y+z))
        if frequency ==6:
            Jx[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x+y+z)*math.cos(time)
            rho[i_spatial] = math.sin(x+y+z)*(-2*math.cos(time)+math.sin(time))
        if frequency ==7:
            Jx[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x+y+z)*math.cos(time)
            rho[i_spatial] = -1*math.cos(x+y+z)*math.sin(time)-2*math.cos(time)*math.sin(x+y+z)     
        if frequency ==8:
            Jx[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = 2*math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(x+y+z)
        if frequency ==9:
            Jx[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(x+y+z)*(2*math.cos(time)-math.sin(time))
        if frequency ==10:
            Jx[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(2*math.cos(x+y+z)-math.sin(x+y+z))
        if frequency ==11:
            Jx[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+2*math.sin(time)*math.sin(x+y+z)
        if frequency ==12:
            Jx[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -1*math.sin(time)*(math.cos(x+y+z)-2*math.sin(x+y+z)) 
        if frequency ==13:
            Jx[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x+y+z)*(2*math.sin(time)-math.cos(time)) 
        if frequency ==14:
            Jx[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(x+y+z)*(math.cos(time)-2*math.sin(time)) 
        if frequency ==15:
            Jx[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*(-2*math.cos(x+y+z)+math.sin(x+y+z)) 
        if frequency ==16:
            Jx[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -2*math.cos(x+y+z)*math.sin(time)-math.cos(time)*math.sin(x+y+z)
        if frequency ==17:
            Jx[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(-2*math.sin(x+y+z)+math.cos(x+y+z)) 
        if frequency ==18:
            Jx[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x+y+z)*(-2*math.cos(time)+math.sin(time))
        if frequency ==19:
            Jx[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -1*math.cos(x+y+z)*math.sin(time)-2*math.cos(time)*math.sin(x+y+z)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 52-71

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = 2*math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(x+y+z)
        if frequency ==1:
            Jx[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(x+y+z)*(2*math.cos(time)-math.sin(time))
        if frequency ==2:
            Jx[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(2*math.cos(x+y+z)-math.sin(x+y+z))
        if frequency ==3:
            Jx[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+2*math.sin(time)*math.sin(x+y+z)
        if frequency ==4:
            Jx[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -1*math.sin(time)*(math.cos(x+y+z)-2*math.sin(x+y+z))
        if frequency ==5:
            Jx[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.sin(x+y+z)*(2*math.sin(time)-math.cos(time))
        if frequency ==6:
            Jx[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(x+y+z)*(math.cos(time)-2*math.sin(time))
        if frequency ==7:
            Jx[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.sin(time)*(-2*math.cos(x+y+z)+math.sin(x+y+z))     
        if frequency ==8:
            Jx[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -2*math.cos(x+y+z)*math.sin(time)-1*math.cos(time)*math.sin(x+y+z) 
        if frequency ==9:
            Jx[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x+y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x+y+z)-2*math.sin(x+y+z))
        if frequency ==10:
            Jx[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x+y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = (-2*math.cos(time)+math.sin(time))*math.sin(x+y+z)
        if frequency ==11:
            Jx[i_spatial] = math.cos(x+y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x+y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)-2*math.cos(time)*math.sin(x+y+z)
        if frequency ==12:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            rho[i_spatial] = -math.cos(y+z)*math.sin(time)*math.sin(x)+math.cos(time)*math.sin(x+y+z)
        if frequency ==13:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*math.sin(x)+math.cos(time-x)*math.sin(y+z)
        if frequency ==14:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(math.cos(y+z)*math.sin(x)+(math.cos(x)-math.sin(x))*math.sin(y+z))
        if frequency ==15:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(math.cos(y+z)*(math.cos(x)+math.sin(x))+math.cos(x)*math.sin(y+z))
        if frequency ==16:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            rho[i_spatial] = -math.cos(x)*math.cos(y+z)*math.sin(time)+math.cos(time)*math.sin(x+y+z)
        if frequency ==17:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*math.sin(x)
        if frequency ==18:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            rho[i_spatial] = math.cos(x)*math.sin(time)*math.sin(y+z)+math.cos(time)*math.sin(x+y+z)
        if frequency ==19:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*math.sin(x)-math.sin(time)*math.sin(x+y+z)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 72-91

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            rho[i_spatial] = -math.sin(time)*(math.cos(y+z)*math.sin(x)+(math.cos(x)-math.sin(x))*math.sin(y+z))
        if frequency ==1:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            rho[i_spatial] = -math.cos(time)*math.sin(x)*math.sin(y+z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==2:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.cos(x)*math.cos(y+z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==3:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            rho[i_spatial] = -math.sin(time)*(math.cos(y+z)*(math.cos(x)+math.sin(x))+math.cos(x)*math.sin(y+z))
        if frequency ==4:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            rho[i_spatial] = -math.cos(time)*math.cos(x)*math.sin(y+z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==5:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            rho[i_spatial] = -math.cos(y+z)*math.sin(time)*math.sin(x)
        if frequency ==6:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(math.cos(y+z)*(math.cos(x)+math.sin(x))-math.sin(x)*math.sin(y+z))
        if frequency ==7:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(x)*math.sin(y+z)     
        if frequency ==8:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(y+z)*math.sin(time)*math.sin(x)
        if frequency ==9:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(2*math.cos(x)*math.cos(y+z)-math.sin(x)*math.sin(y+z))
        if frequency ==10:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x)*math.cos(y+z)*math.sin(time)
        if frequency ==11:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y+z)-(math.cos(x)+math.sin(x))*math.sin(y+z))
        if frequency ==12:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            rho[i_spatial] = math.cos(x)*math.cos(t-y-z)-math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==13:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(math.cos(y+z)*(math.cos(x)+math.sin(x))-math.sin(x)*math.sin(y+z))
        if frequency ==14:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(x)*math.sin(y+z)
        if frequency ==15:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(y+z)*math.sin(time)*math.sin(x)
        if frequency ==16:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y+z)-2*math.sin(x)*math.sin(y+z))
        if frequency ==17:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x)*math.cos(y+z)*math.sin(time)
        if frequency ==18:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y+z)-(math.cos(x)+math.sin(x))*math.sin(y+z))
        if frequency ==19:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            rho[i_spatial] = math.cos(x)*math.cos(time-y-z)-math.cos(time)*math.sin(x)*math.sin(y+z)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 92-111

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)+math.cos(time)*math.cos(y+z)*math.sin(x)
        if frequency ==1:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            rho[i_spatial] = math.sin(time)*(-math.cos(x)*math.cos(y+z)+2*math.sin(x)*math.sin(y+z))
        if frequency ==2:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            rho[i_spatial] = math.sin(time)*(-math.cos(y+z)*(math.cos(x)+math.sin(x))+math.sin(x)*math.sin(y+z))
        if frequency ==3:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)-math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==4:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.cos(x)*math.cos(y+z)-math.cos(x+y+z)*math.sin(time)
        if frequency ==5:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)-math.cos(time)*math.cos(x)*math.sin(y+z)
        if frequency ==6:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            rho[i_spatial] = math.sin(time)*(-math.cos(x)*math.cos(y+z)+(math.cos(x)+math.sin(x))*math.sin(y+z))
        if frequency ==7:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = 2*math.cos(time)*math.cos(y+z)*math.sin(x)-math.cos(x)*math.sin(time)*math.sin(y+z)     
        if frequency ==8:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(y+z)*(-math.cos(x)*math.sin(time)+2*math.cos(time)*math.sin(x))
        if frequency ==9:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*(math.cos(x)+2*math.sin(x))
        if frequency ==10:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.sin(x)*(2*math.cos(y+z)-math.sin(y+z))
        if frequency ==11:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(2*math.cos(time)*math.cos(y+z)+math.sin(time)*math.sin(y+z))
        if frequency ==12:
            Jx[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*math.sin(x)
        if frequency ==13:
            Jx[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(y+z)*(2*math.cos(time)+math.sin(time))*math.sin(x)
        if frequency ==14:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -2*math.cos(y+z)*math.sin(time)*math.sin(x)+math.cos(time)*math.cos(x)*math.sin(y+z)
        if frequency ==15:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(y+z)*math.sin(time)*(math.cos(x)+2*math.sin(x))
        if frequency ==16:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(y+z)*(math.cos(time)*math.cos(x)-2*math.sin(time)*math.sin(x))
        if frequency ==17:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(x)*(2*math.cos(y+z)*math.sin(time)+math.cos(time)*math.sin(y+z))
        if frequency ==18:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*math.sin(x)*(-2*math.cos(y+z)+math.sin(y+z))
        if frequency ==19:
            Jx[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(y+z)*(math.cos(time)+2*math.sin(time))*math.sin(x)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 112-131

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(y+z)*math.sin(time)*math.sin(x)
        if frequency ==1:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)-2*math.sin(x))*math.sin(y+z)
        if frequency ==2:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x)*math.cos(y+z)*math.sin(time)-2*math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==3:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -(math.cos(x)*math.sin(time)+2*math.cos(time)*math.sin(x))*math.sin(y+z)
        if frequency ==4:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -3*math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==5:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = (-2*math.cos(time)+math.sin(time))*math.sin(x)*math.sin(y+z)
        if frequency ==6:
            Jx[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.sin(x)*(math.cos(y+z)+2*math.sin(y+z))
        if frequency ==7:
            Jx[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(x)*(math.cos(y+z)*math.sin(time)-2*math.cos(time)*math.sin(y+z))  
        if frequency ==8:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x)*(2*math.cos(y+z)+math.sin(y+z))
        if frequency ==9:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(x)*math.cos(y+z)*(2*math.cos(time)-math.sin(time))
        if frequency ==10:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(x)*(2*math.cos(time)*math.cos(y+z)-math.sin(time)*math.sin(y+z))
        if frequency ==11:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = 3*math.cos(time)*math.cos(x)*math.cos(y+z)
        if frequency ==12:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = 2*math.cos(time)*math.cos(x)*math.cos(y+z)+math.sin(time)*math.sin(x)*math.sin(y+z)
        if frequency ==13:
            Jx[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*(2*math.cos(x)-math.sin(x))
        if frequency ==14:
            Jx[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(y+z)*(2*math.cos(time)*math.cos(x)+math.sin(time)*math.sin(x))
        if frequency ==15:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(x)*(-2*math.cos(y+z)*math.sin(time)+math.cos(time)*math.sin(y+z))
        if frequency ==16:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -3*math.cos(x)*math.cos(y+z)*math.sin(time)
        if frequency ==17:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x)*math.sin(time)*(2*math.cos(y+z)+math.sin(y+z))
        if frequency ==18:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(x)*math.cos(y+z)*(math.cos(time)-2*math.sin(time))
        if frequency ==19:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -2*math.cos(x)*math.cos(y+z)*math.sin(time)-math.cos(time)*math.sin(x)*math.sin(y+z)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 132-151

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(y+z)*(2*math.cos(x)*math.sin(time)+math.cos(time)*math.sin(x))
        if frequency ==1:
            Jx[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(y+z)*math.sin(time)*(-2*math.cos(x)+math.sin(x))
        if frequency ==2:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(y+z)*math.sin(time)*math.sin(x)+math.cos(time)*math.sin(x+y+z)
        if frequency ==3:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*math.sin(x)+math.cos(time-x)*math.sin(y+z)
        if frequency ==4:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(y+z)*math.sin(x)+(math.cos(x)-math.sin(x))*math.sin(y+z)
        if frequency ==5:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(y+z)*(math.cos(x)+math.sin(x))+math.cos(x)*math.sin(y+z))
        if frequency ==6:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x)*math.cos(y+z)*math.sin(time)+math.cos(time)*math.sin(x+y+z)
        if frequency ==7:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*math.sin(x) 
        if frequency ==8:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(x)*math.sin(time)*math.sin(y+z)+math.cos(time)*math.sin(x+y+z)
        if frequency ==9:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y+z)*math.sin(x)-math.sin(time)*math.sin(x+y+z)
        if frequency ==10:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(y+z)*math.sin(x)+(math.cos(x)-math.sin(x))*math.sin(y+z))
        if frequency ==11:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.sin(x)*math.sin(y+z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==12:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x)*math.cos(y+z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==13:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(y+z)*(math.cos(x)+math.sin(x))+math.cos(x)*math.sin(y+z))
        if frequency ==14:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.cos(x)*math.sin(y+z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==15:
            Jx[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(y+z)*math.sin(time)*math.sin(x)
        if frequency ==16:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(y+z)*(math.cos(x)+math.sin(x))-math.sin(x)*math.sin(y+z))
        if frequency ==17:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(x)*math.sin(y+z)
        if frequency ==18:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(y+z)*math.sin(time)*math.sin(x)
        if frequency ==19:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(2*math.cos(x)*math.cos(y+z)-math.sin(x)*math.sin(y+z))
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 152 -171

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x)*math.cos(y+z)*math.sin(time)
        if frequency ==1:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y+z)-(math.cos(x)+math.sin(x))*math.sin(y+z))
        if frequency ==2:
            Jx[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(x)*math.cos(time-y-z)-math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==3:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(y+z)*(math.cos(x)+math.sin(x))-math.sin(x)*math.sin(y+z))
        if frequency ==4:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(x)*math.sin(y+z)
        if frequency ==5:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(y+z)*math.sin(time)*math.sin(x)
        if frequency ==6:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y+z)-2*math.sin(x)*math.sin(y+z))
        if frequency ==7:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x)*math.cos(y+z)*math.sin(time)
        if frequency ==8:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y+z)-(math.cos(x)+math.sin(x))*math.sin(y+z))
        if frequency ==9:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jy[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(x)*math.cos(time-y-z)-math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==10:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)+math.cos(time)*math.cos(y+z)*math.sin(x)
        if frequency ==11:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(x)*math.cos(y+z)+2*math.sin(x)*math.sin(y+z))
        if frequency ==12:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.sin(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(y+z)*(math.cos(x)+math.sin(x))+math.sin(x)*math.sin(y+z))
        if frequency ==13:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.sin(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)-math.cos(time)*math.sin(x)*math.sin(y+z)
        if frequency ==14:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x)*math.sin(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x)*math.cos(y+z)-math.cos(x+y+z)*math.sin(time)
        if frequency ==15:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x)*math.cos(y+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)-math.cos(time)*math.cos(x)*math.sin(y+z)
        if frequency ==16:
            Jx[i_spatial] = math.cos(x)*math.sin(y+z)*math.cos(time)
            Jy[i_spatial] = math.cos(x)*math.cos(y+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(x)*math.cos(y+z)+(math.cos(x)+math.sin(x))*math.sin(y+z))
        if frequency ==17:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            rho[i_spatial] = -math.cos(x+z)*math.sin(time)*math.sin(y)+math.cos(time)*math.sin(x+y+z)
        if frequency ==18:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+z)*math.sin(y)+math.cos(time-y)*math.sin(x+z)
        if frequency ==19:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(math.cos(x+z)*math.sin(y)+(math.cos(y)-math.sin(y))*math.sin(x+z))
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 172 - 191

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(math.cos(x+z)*(math.cos(y)+math.sin(y))+math.cos(y)*math.sin(x+z))
        if frequency ==1:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            rho[i_spatial] = -math.cos(y)*math.cos(x+z)*math.sin(time)+math.cos(time)*math.sin(x+y+z)
        if frequency ==2:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+z)*math.sin(y)
        if frequency ==3:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            rho[i_spatial] = math.cos(y)*math.sin(time)*math.sin(x+z)+math.cos(time)*math.sin(x+y+z)
        if frequency ==4:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+z)*math.sin(y)-math.sin(time)*math.sin(x+y+z)
        if frequency ==5:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            rho[i_spatial] = -math.sin(time)*(math.cos(x+z)*math.sin(y)+(math.cos(y)-math.sin(y))*math.sin(x+z))
        if frequency ==6:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            rho[i_spatial] = -math.cos(time)*math.sin(y)*math.sin(x+z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==7:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.cos(y)*math.cos(x+z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==8:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*(math.cos(x)*math.cos(y+z)-(math.cos(x)+math.sin(x))*math.sin(y+z))
        if frequency ==9:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            rho[i_spatial] = -math.cos(time)*math.cos(y)*math.sin(x+z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==10:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            rho[i_spatial] = -math.cos(x+z)*math.sin(time)*math.sin(y)
        if frequency ==11:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(math.cos(x+z)*(math.cos(y)+math.sin(y))-math.sin(y)*math.sin(x+z))
        if frequency ==12:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(y)*math.sin(x+z)
        if frequency ==13:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x+z)*math.sin(time)*math.sin(y)
        if frequency ==14:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(2*math.cos(y)*math.cos(x+z)-math.sin(y)*math.sin(x+z)
        if frequency ==15:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(y)*math.cos(x+z)*math.sin(time)
        if frequency ==16:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(math.cos(y)*math.cos(x+z)-(math.cos(y)+math.sin(y))*math.sin(x+z))
        if frequency ==17:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            rho[i_spatial] = math.cos(y)*math.cos(time-x-z)-math.cos(time)*math.sin(y)*math.sin(x+z)
        if frequency ==18:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(math.cos(x+z)*(math.cos(y)+math.sin(y))-math.sin(y)*math.sin(x+z)
        if frequency ==19:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(y)*math.sin(x+z)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 192 - 211

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x+z)*math.sin(time)*math.sin(y)
        if frequency ==1:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(math.cos(y)*math.cos(x+z)-2*math.sin(y)*math.sin(x+z))
        if frequency ==2:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(y)*math.cos(x+z)*math.sin(time)
        if frequency ==3:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*(math.cos(y)*math.cos(x+z)-(math.cos(y)+math.sin(y))*math.sin(x+z))
        if frequency ==4:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            rho[i_spatial] = math.cos(y)*math.cos(time-x-z)-math.cos(time)*math.sin(y)*math.sin(x+z)
        if frequency ==5:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)+math.cos(time)*math.cos(x+z)*math.sin(y)
        if frequency ==6:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            rho[i_spatial] = math.sin(time)*(-math.cos(y)*math.cos(x+z)+2*math.sin(y)*math.sin(x+z))
        if frequency ==7:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            rho[i_spatial] = math.sin(time)*(-math.cos(x+z)*(math.cos(y)+math.sin(y))+math.sin(y)*math.sin(x+z))
        if frequency ==8:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)-math.cos(time)*math.sin(y)*math.sin(x+z)
        if frequency ==9:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            rho[i_spatial] = math.cos(time)*math.cos(y)*math.cos(x+z)-math.cos(x+y+z)*math.sin(time)
        if frequency ==10:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)-math.cos(time)*math.cos(y)*math.sin(x+z)
        if frequency ==11:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            rho[i_spatial] = math.sin(time)*(-math.cos(y)*math.cos(x+z)+(math.cos(y)+math.sin(y))*math.sin(x+z))
        if frequency ==12:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x+z)*math.sin(time)*math.sin(y)+math.cos(time)*math.sin(x+y+z)
        if frequency ==13:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+z)*math.sin(y)+math.cos(time-y)*math.sin(x+z)
        if frequency ==14:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x+z)*math.sin(y)+(math.cos(y)-math.sin(y))*math.sin(x+z))
        if frequency ==15:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x+z)*(math.cos(y)+math.sin(y))+math.cos(y)*math.sin(x+z))
        if frequency ==16:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(y)*math.cos(x+z)*math.sin(time)+math.cos(time)*math.sin(x+y+z)
        if frequency ==17:
            Jx[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+z)*math.sin(y)
        if frequency ==18:
            Jx[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(y)*math.sin(time)*math.sin(x+z)+math.cos(time)*math.sin(x+y+z)
        if frequency ==19:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = Jx[i_spatial]
            Jz[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            rho[i_spatial] = math.cos(time)*math.cos(x+z)*math.sin(y)-math.sin(time)*math.sin(x+y+z)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 212 - 231

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(x+z)*math.sin(y)+(math.cos(y)-math.sin(y))*math.sin(x+z))
        if frequency ==1:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.sin(y)*math.sin(x+z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==2:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y)*math.cos(x+z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==3:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.sin(time)*(math.cos(x+z)*(math.cos(y)+math.sin(y))+math.cos(y)*math.sin(x+z))
        if frequency ==4:
            Jx[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(time)*math.cos(y)*math.sin(x+z)-math.sin(time)*math.sin(x+y+z)
        if frequency ==5:
            Jx[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x+z)*math.sin(time)*math.sin(y)
        if frequency ==6:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x+z)*(math.cos(y)+math.sin(y))-math.sin(y)*math.sin(x+z))
        if frequency ==7:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(y)*math.sin(x+z)
        if frequency ==8:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x+z)*math.sin(time)*math.sin(y)
        if frequency ==9:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(2*math.cos(y)*math.cos(x+z)-math.sin(y)*math.sin(x+z))
        if frequency ==10:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(y)*math.cos(x+z)*math.sin(time)
        if frequency ==11:
            Jx[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(y)*math.cos(x+z)-(math.cos(y)+math.sin(y))*math.sin(x+z))
        if frequency ==12:
            Jx[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(y)*math.cos(time-x-z)-math.cos(time)*math.sin(y)*math.sin(x+z)
        if frequency ==13:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(x+z)*(math.cos(y)+math.sin(y))-math.sin(y)*math.sin(x+z))
        if frequency ==14:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)+math.sin(time)*math.sin(y)*math.sin(x+z)
        if frequency ==15:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(x+z)*math.sin(time)*math.sin(y)
        if frequency ==16:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(y)*math.cos(x+z)-2*math.sin(y)*math.sin(x+z))
        if frequency ==17:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+y+z)-math.cos(y)*math.cos(x+z)*math.sin(time)
        if frequency ==18:
            Jx[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*(math.cos(y)*math.cos(x+z)-(math.cos(y)+math.sin(y))*math.sin(x+z))
        if frequency ==19:
            Jx[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(y)*math.cos(time-x-z)-math.cos(time)*math.sin(y)*math.sin(x+z)
    return Jx, Jy, Jz, rho

# %% [markdown]
# # 232 - 251

# %%
def areal_position(i, d, left_boundary):
    return i*d + d/2 + left_boundary

# generate sinusodial sources of rho and J
def generate_rho_J(frequency,time, dx, dy, dz, x_left_boundary, y_left_boundary, z_left_boundary, \
                   x_grid_size, y_grid_size, z_grid_size, total_spatial_grid_size):    
    rho, Jx, Jy, Jz = (np.empty(total_spatial_grid_size, dtype=np.float32) for _ in range(4))
    for i_spatial in range(total_spatial_grid_size):
        iz = i_spatial%z_grid_size
        iz_rest = i_spatial//z_grid_size
        iy = iz_rest%y_grid_size
        iy_rest = iz_rest//y_grid_size
        ix = iy_rest%x_grid_size
        x, y, z = areal_position(ix, dx, x_left_boundary), areal_position(iy, dy, y_left_boundary), areal_position(iz, dz, z_left_boundary)
        if frequency ==0:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)+math.cos(time)*math.cos(x+z)*math.sin(y)
        if frequency ==1:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(y)*math.cos(x+z)+2*math.sin(y)*math.sin(x+z))
        if frequency ==2:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(x+z)*(math.cos(y)+math.sin(y))+math.sin(y)*math.sin(x+z))
        if frequency ==3:
            Jx[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)-math.cos(time)*math.sin(y)*math.sin(x+z)
        if frequency ==4:
            Jx[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(y)*math.cos(x+z)-math.cos(x+y+z)*math.sin(time)
        if frequency ==5:
            Jx[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = -math.cos(x+y+z)*math.sin(time)-math.cos(time)*math.cos(y)*math.sin(x+z)
        if frequency ==6:
            Jx[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jy[i_spatial]
            rho[i_spatial] = math.sin(time)*(-math.cos(y)*math.cos(x+z)+(math.cos(y)+math.sin(y))*math.sin(x+z))
        if frequency ==7:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = 2*math.cos(time)*math.cos(x+z)*math.sin(y)-math.cos(y)*math.sin(time)*math.sin(x+z)
        if frequency ==8:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(x+z)*(-math.cos(y)*math.sin(time)+2*math.cos(time)*math.sin(y))
        if frequency ==9:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+z)*(math.cos(y)+2*math.sin(y))
        if frequency ==10:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.sin(y)*(2*math.cos(x+z)-math.sin(x+z))
        if frequency ==11:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.sin(y)*(2*math.cos(time)*math.cos(x+z)+math.sin(time)*math.sin(x+z))
        if frequency ==12:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(time)*math.cos(x+z)*math.sin(y)
        if frequency ==13:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jy[i_spatial] = math.cos(y)*math.cos(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(x+z)*(2*math.cos(time)+math.sin(time))*math.sin(y)
        if frequency ==14:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -2*math.cos(x+z)*math.sin(time)*math.sin(y)+math.cos(time)*math.cos(y)*math.sin(x+z)
        if frequency ==15:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x+z)*math.sin(time)*(math.cos(y)+2*math.sin(y))
        if frequency ==16:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.sin(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.cos(x+z)*(math.cos(time)*math.cos(y)-2*math.sin(time)*math.sin(y))
        if frequency ==17:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.sin(y)*(2*math.cos(x+z)*math.sin(time)+math.cos(time)*math.sin(x+z))
        if frequency ==18:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.cos(y)*math.sin(x+z)*math.cos(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = math.sin(time)*math.sin(y)*(-2*math.cos(x+z)+math.sin(x+z))
        if frequency ==19:
            Jx[i_spatial] = math.sin(y)*math.sin(x+z)*math.cos(time)
            Jy[i_spatial] = math.cos(y)*math.cos(x+z)*math.sin(time)
            Jz[i_spatial] = Jx[i_spatial]
            rho[i_spatial] = -math.cos(x+z)*(math.cos(time)+2*math.sin(time))*math.sin(y)
    return Jx, Jy, Jz, rho
